# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdelkhalek2016/Artificial-Intelligence-Important-Documents-Collections/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello colab')
# Out:
# hello colab

# %%
import numpy as np

# %%
# %%time
image=np.random.randint(0,255,(1000,1000))
# Out:
# CPU times: user 7.26 ms, sys: 3.82 ms, total: 11.1 ms
# Wall time: 10.7 ms

# %%
import matplotlib.pyplot as plt

# %%
drawimage=plt.plot(image)
